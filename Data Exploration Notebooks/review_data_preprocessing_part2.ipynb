# %%
import pandas as pd

# %%
review_data = pd.read_pickle('houston_restaurent_reviews.pickle')
rating_data = pd.read_pickle('houston_rest_df_1.pickle')

# %%
review_data
# Out:
#                        user_id              name           time  rating  \
# 0        108973466903602523839        Candi Redd  1629502461357       5
# 1        113137095513792040022     Paul Gantcher  1629052063842       5
# 2        105026170218579952045         Rio Abbas  1630887172418       4
# 3        117177685398357548836     Jaleh Sadeghi  1629873058680       5
# 4        110026761515345451532  Xavier Fernandez  1629744532145       5
# ...                        ...               ...            ...     ...
# 2677856  118021670361489545825       Jaimee Coco  1552585750263       5
# 2677857  109127362531452145703        Ana Oaxaca  1583723163388       5
# 2677858  103112817127658876915               S D  1561571141240       5
# 2677859  112898242233150784696      Seth Terrell  1568514580625       4
# 2677860  107012186280666655225    Luis Santacruz  1552378350653       5
#
#                                                       text  \
# ...

# %%
rating_gmap_ids = rating_data['gmap_id']

# %%
len(rating_gmap_ids)
# Out:
# 4214

# %%
review_data_filtered = review_data[review_data['gmap_id'].isin(rating_gmap_ids)]

# %%
review_gmap_ids = review_data_filtered['gmap_id'].unique().tolist()

# %%
len(review_gmap_ids)
# Out:
# 4214

# %%
rating_data_filtered = rating_data[rating_data['gmap_id'].isin(review_gmap_ids)]

# %%
rating_data_filtered.shape
# Out:
# (4214, 15)

# %%
review_data_filtered.drop(['time', 'resp'], axis=1, inplace=True)
# Out:
# /var/folders/m_/xyzbyy5x5jvf43dnkgjcssr00000gn/T/ipykernel_4351/1511056810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_data_filtered.drop(['time', 'resp'], axis=1, inplace=True)

# %%
review_data_filtered
# Out:
#                        user_id                name  rating  \
# 214      114487196325233628478          Squibby 38       5
# 215      116945698148452694551      Teresa peacock       5
# 216      104500115420807096750        Kevin Taddeo       5
# 217      106184891951725764092             Chris J       5
# 218      100948115169279036661        Mike Foroodi       2
# ...                        ...                 ...     ...
# 2677667  105927635615578186040        Shane Willis       4
# 2677668  103501623300671172763         Erik Rydman       3
# 2677669  107176921626504024659  Digvijay Chintawar       3
# 2677670  109401334586066157495              EbEver       5
# 2677671  109510925063969790483             Wayne G       4
#
#                                                       text  \
# 214      Found this place by accident, decided to try i...
# 215      Super yummy! Been looking for a good pad Thai ...
# 216      New owner. Fantastic food and service. The red...
# ...

# %%
review_data_filtered.to_pickle('houston_restaurent_reviews_1.pickle')
rating_data_filtered.to_pickle('houston_rest_df_1.pickle')
