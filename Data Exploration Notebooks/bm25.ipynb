# %%
! pip install rank-bm25

# %%
import pickle
import pandas as pd
from rank_bm25 import BM25Okapi

# %%
with open('restaurent_docs.pickle', 'rb') as f:
    docs_df = pickle.load(f)

# %%
docs_df.head(7)
# Out:
#                              name  \
# 0                          Fadi's
# 1                        Jus' Mac
# 2                     chill works
# 3  Tacos Adrian's Puerto Vallarta
# 4           Fire Wings Westheimer
# 5                           Mobil
# 6                    Magic Island
#
#                                              address  \
# 0      Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 1    Jus' Mac, 5640 Westheimer Rd, Houston, TX 77056
# 2  chill works, 3509 Elgin St Suite 200, Houston,...
# 3  Tacos Adrian's Puerto Vallarta, 9705 Synott Rd...
# 4  Fire Wings Westheimer, 8401 Westheimer Rd #110...
# 5          Mobil, 14502 Market St, Houston, TX 77015
# 6  Magic Island, 2215 Southwest Fwy, Houston, TX ...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
# 1  0x8640c15f393c8e2b:0xcebbc17fcff328bf        None  29.738526 -95.475659
# ...

# %%
documents = docs_df['doc_information'].to_list()

# %%
document_ids = [i for i in range(len(documents))]

# %%
tokenized_docs = [doc.split(" ") for doc in documents]

# %%
bm25 = BM25Okapi(tokenized_docs)

# %%
query = "Mobil Gas Station"
query_tokens = query.split(" ")

# Get document scores
doc_scores = bm25.get_scores(query_tokens)

# %%
doc_scores_with_ids = list(zip(document_ids, doc_scores, docs_df['avg_rating'].to_list()))

# %%
sorted_docs_with_ids = sorted(doc_scores_with_ids, key=lambda x: -x[1])

# %%
sorted_docs_with_ids
# Out:
# [(120, 17.25916402710239, 2.8),
#  (496, 17.21838527858391, 3.7),
#  (575, 17.046130946699066, 3.1),
#  (4332, 16.37641531031281, 4.1),
#  (1668, 15.819020078204773, 4.2),
#  (922, 15.64750959454305, 3.4),
#  (2829, 13.82507637506325, 4.4),
#  (982, 12.63970631730746, 4.2),
#  (3950, 12.278713930644956, 3.4),
#  (7023, 11.503814720440985, 3.3),
#  (3642, 10.993750891764698, 3.8),
#  (4072, 10.310017003356515, 4.1),
#  (4743, 9.547953316671133, 3.7),
#  (1246, 9.518442118219543, 3.4),
#  (1440, 9.332411925402841, 3.7),
#  (7268, 9.225364449293597, 4.1),
#  (314, 9.043357075854454, 3.6),
#  (4982, 9.040603947444007, 3.6),
#  (5605, 9.028235585501452, 4.0),
#  (1568, 9.01111116267723, 4.5),
#  (1449, 9.007696682443486, 4.0),
#  (3907, 8.992694114261111, 3.9),
#  (3244, 8.954298126947274, 4.4),
#  (2483, 8.937213004959291, 3.5),
#  (5540, 8.784612224079286, 4.4),
#  (1653, 8.641387022625906, 3.4),
#  (2006, 8.516747484948702, 2.7),
#  (4457, 8.44526546879635, 3.7),
# ...

# %%
ind = [i for i, _ , _ in sorted_docs_with_ids[:10]]

# %%
docs_df.loc[ind,:]
# Out:
#                name                                            address  \
# 120     Speedy Stop       Speedy Stop, 4981 Hwy 6 N, Houston, TX 77084
# 496           Shell  Shell, 7416 S Sam Houston Pkwy W, Houston, TX ...
# 575           Shell          Shell, 511 Lockwood Dr, Houston, TX 77011
# 4332          Shell  Shell, 2322 Little York Rd, Houston, TX 77093,...
# 1668          Shell         Shell, 301 W Tidwell Rd, Houston, TX 77091
# 922           Shell  Shell, 14106 W W Lake Houston Pkwy, Houston, T...
# 2829      Taco Real       Taco Real, 9004 North Fwy, Houston, TX 77037
# 982   Little Ginger  Little Ginger, 2855 W Lake Houston Pkwy, Kingw...
# 3950    Burger King  Burger King, 12404 N Gessner Rd, Houston, TX 7...
# 7023    Burger King  Burger King, 7015 N Sam Houston Pkwy E, Humble...
#
#                                     gmap_id  \
# 120   0x8640d9ff4fdee403:0x8a2ee7569adfaf82
# 496   0x8640e96722a51325:0x921e172012cd6963
# 575   0x8640be97d4c962f7:0xe3d4d53f04899f30
# ...
